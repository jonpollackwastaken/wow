# %%
def compare_strings(s1, s2):
    if s1!=s2:        
        for i in range(0,len(s1)):
            print(s1[i], s2[i], '<<<<<<'* (s1[i]!=s2[i]))
    else:
        print("Matched!")

# %%
s1 = '''^1^T^Soperations^T^SMailing^T^S#Default^T^Srestock^b^SkeepQty^N0^SmaxQtyEnabled^b^Starget^S^SrestockSources^T^Sguild^b^Sbank^b^t^SmaxQty^N10^t^t^SAuctioning^T^SBlindweed^T^SaboveMax^SmaxPrice^SnormalPrice^S8044^Sduration^N3^SmatchStackSize^b^SkeepQuantity^N0^SpostCap^N4^SbidPercent^N1^SstackSizeIsCap^B^SmaxPrice^S9653^SignoreLowDuration^N0^SstackSize^N5^SkeepPosted^N0^Sundercut^S1c^SmaxExpires^N0^SpriceReset^SminPrice^ScancelRepostThreshold^S1g^ScancelRepost^B^ScancelUndercut^B^SminPrice^S7400^SkeepQtySources^T^t^Sblacklist^S^t^t^SCrafting^T^S#Default^T^SminRestock^N1^SminProfit^S100g^ScraftPriceMethod^S^SmaxRestock^N3^t^t^SWarehousing^T^S#Default^T^SstackSize^N0^SmoveQuantity^N0^SkeepBankQuantity^N0^SrestockKeepBankQuantity^N0^SrestockQuantity^N0^SrestockStackSize^N0^SkeepBagQuantity^N0^t^t^SVendoring^T^S#Default^T^SvsMarketValue^Sdbmarket^SenableBuy^B^SvsMaxMarketValue^S0c^SsellAfterExpired^N20^SvsDestroyValue^Sdestroy^SrestockQty^N0^SkeepQty^N0^SvsMaxDestroyValue^S0c^SrestockSources^T^Salts_ah^b^Sah^b^Sguild^b^Salts^b^Smail^b^Sbank^b^t^SsellSoulbound^b^SenableSell^B^t^t^SShopping^T^SBlindweed^T^SevenStacks^b^SshowAboveMaxPrice^B^SmaxPrice^S6435^SrestockQuantity^N20^SrestockSources^T^Salts^b^Sauctions^B^Sguild^b^Sbank^b^t^t^t^SSniper^T^S#Default^T^SbelowPrice^Smax(vendorsell,~`ifgt(DBRegionMarketAvg,~`250000g,~`0.8,~`ifgt(DBRegionMarketAvg,~`100000g,~`0.7,~`ifgt(DBRegionMarketAvg,~`50000g,~`0.6,~`ifgt(DBRegionMarketAvg,~`25000g,~`0.5,~`ifgt(DBRegionMarketAvg,~`10000g,~`0.4,~`ifgt(DBRegionMarketAvg,~`5000g,~`0.3,~`ifgt(DBRegionMarketAvg,~`2000g,~`0.2,~`ifgt(DBRegionMarketAvg,~`1000g,~`0.1,~`0.05))))))))~`*~`DBRegionMarketAvg)^t^t^t^SgroupOperations^T^SBlindweed^T^SMailing^T^N1^S#Default^Soverride^B^t^SAuctioning^T^N1^SBlindweed^Soverride^B^t^SCrafting^T^N1^S#Default^Soverride^B^t^SWarehousing^T^N1^S#Default^Soverride^B^t^SVendoring^T^N1^S#Default^Soverride^B^t^SShopping^T^N1^SBlindweed^Soverride^B^t^SSniper^T^N1^S#Default^Soverride^B^t^t^t^SgroupExport^Sgroup:Blindweed,i:8839^t^^'''

# %%
s2 = '''^1^T^Soperations^T^SMailing^T^S#Default^T^Srestock^b^SkeepQty^N0^SmaxQtyEnabled^b^Starget^S^SrestockSources^T^Sguild^b^Sbank^b^t^SmaxQty^N10^t^t^SAuctioning^T^SBlindweed^T^SaboveMax^SmaxPrice^SnormalPrice^S8044^Sduration^N3^SmatchStackSize^b^SkeepQuantity^N0^SpostCap^N4^SbidPercent^N1^SstackSizeIsCap^B^SmaxPrice^S9653^SignoreLowDuration^N0^SstackSize^N5^SkeepPosted^N0^Sundercut^S1c^SmaxExpires^N0^SpriceReset^Snone^ScancelRepostThreshold^S1g^ScancelRepost^B^ScancelUndercut^B^SminPrice^S7400^SkeepQtySources^T^t^Sblacklist^S^t^t^SCrafting^T^S#Default^T^SminRestock^N1^SminProfit^S100g^ScraftPriceMethod^S^SmaxRestock^N3^t^t^SWarehousing^T^S#Default^T^SstackSize^N0^SmoveQuantity^N0^SkeepBankQuantity^N0^SrestockKeepBankQuantity^N0^SrestockQuantity^N0^SrestockStackSize^N0^SkeepBagQuantity^N0^t^t^SVendoring^T^S#Default^T^SvsMarketValue^Sdbmarket^SenableBuy^B^SvsMaxMarketValue^S0c^SsellAfterExpired^N20^SvsDestroyValue^Sdestroy^SrestockQty^N0^SkeepQty^N0^SvsMaxDestroyValue^S0c^SrestockSources^T^Salts_ah^b^Sah^b^Sguild^b^Salts^b^Smail^b^Sbank^b^t^SsellSoulbound^b^SenableSell^B^t^t^SShopping^T^SBlindweed^T^SevenStacks^b^SshowAboveMaxPrice^B^SmaxPrice^S6435^SrestockQuantity^N20^SrestockSources^T^Salts^b^Sauctions^B^Sguild^b^Sbank^b^t^t^t^SSniper^T^S#Default^T^SbelowPrice^Smax(vendorsell,~`ifgt(DBRegionMarketAvg,~`250000g,~`0.8,~`ifgt(DBRegionMarketAvg,~`100000g,~`0.7,~`ifgt(DBRegionMarketAvg,~`50000g,~`0.6,~`ifgt(DBRegionMarketAvg,~`25000g,~`0.5,~`ifgt(DBRegionMarketAvg,~`10000g,~`0.4,~`ifgt(DBRegionMarketAvg,~`5000g,~`0.3,~`ifgt(DBRegionMarketAvg,~`2000g,~`0.2,~`ifgt(DBRegionMarketAvg,~`1000g,~`0.1,~`0.05))))))))~`*~`DBRegionMarketAvg)^t^t^t^SgroupOperations^T^SBlindweed^T^SMailing^T^N1^S#Default^Soverride^B^t^SAuctioning^T^N1^SBlindweed^Soverride^B^t^SCrafting^T^N1^S#Default^Soverride^B^t^SWarehousing^T^N1^S#Default^Soverride^B^t^SVendoring^T^N1^S#Default^Soverride^B^t^SShopping^T^N1^SBlindweed^Soverride^B^t^SSniper^T^N1^S#Default^Soverride^B^t^t^t^SgroupExport^Sgroup:Blindweed,i:8839^t^^'''

# %%
compare_strings(s1,s2)
# Out:
# ^ ^
# 1 1
# ^ ^
# T T
# ^ ^
# S S
# o o
# p p
# e e
# r r
# a a
# t t
# i i
# o o
# n n
# s s
# ^ ^
# T T
# ^ ^
# S S
# M M
# a a
# i i
# l l
# i i
# n n
# g g
# ^ ^
# T T
# ^ ^
# S S
# # #
# D D
# e e
# f f
# a a
# u u
# l l
# t t
# ^ ^
# T T
# ^ ^
# S S
# r r
# e e
# s s
# t t
# o o
# c c
# k k
# ^ ^
# b b
# ^ ^
# S S
# k k
# e e
# e e
# p p
# Q Q
# t t
# y y
# ^ ^
# N N
# 0 0
# ^ ^
# S S
# m m
# a a
# x x
# Q Q
# t t
# y y
# E E
# n n
# a a
# b b
# l l
# e e
# d d
# ^ ^
# b b
# ^ ^
# S S
# t t
# a a
# r r
# g g
# e e
# t t
# ^ ^
# S S
# ^ ^
# S S
# r r
# e e
# s s
# t t
# o o
# c c
# k k
# S S
# o o
# u u
# r r
# c c
# e e
# s s
# ^ ^
# T T
# ^ ^
# S S
# g g
# u u
# i i
# l l
# d d
# ^ ^
# b b
# ^ ^
# S S
# b b
# a a
# n n
# k k
# ^ ^
# b b
# ^ ^
# t t
# ^ ^
# S S
# m m
# a a
# x x
# Q Q
# t t
# y y
# ^ ^
# N N
# 1 1
# 0 0
# ^ ^
# t t
# ^ ^
# t t
# ^ ^
# S S
# A A
# u u
# c c
# t t
# i i
# o o
# n n
# i i
# n n
# g g
# ^ ^
# T T
# ^ ^
# S S
# B B
# l l
# i i
# n n
# d d
# w w
# ...
